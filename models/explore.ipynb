# %% [markdown]
# Content
# The "data.csv" file contains more than 175.000 songs collected from Spotify Web API, and also you can find data grouped by artist, year, or genre in the data section.
# More on Spotify audio features, click here
# More on other Spotify track features, click here
#
# Primary:
# - id (Id of track generated by Spotify)
# Numerical:
# - acousticness (Ranges from 0 to 1)
# - danceability (Ranges from 0 to 1)
# - energy (Ranges from 0 to 1)
# - duration_ms (Integer typically ranging from 200k to 300k)
# - instrumentalness (Ranges from 0 to 1)
# - valence (Ranges from 0 to 1)
# - popularity (Ranges from 0 to 100)
# - tempo (Float typically ranging from 50 to 150)
# - liveness (Ranges from 0 to 1)
# - loudness (Float typically ranging from -60 to 0)
# - speechiness (Ranges from 0 to 1)
# - year (Ranges from 1921 to 2020)
# Dummy:
# - mode (0 = Minor, 1 = Major)
# - explicit (0 = No explicit content, 1 = Explicit content)
# Categorical:
# - key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
# - artists (List of artists mentioned)
# - release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
# - name (Name of the song)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('Sentences_15klyrics_mls_20.csv')

# %%
df2 = pd.read_csv('sentences_15klyrics.csv')

# %%
df2
# Out:
#              artist                     song_name  song_id  \
# 0       Mamie Smith      Keep A Song In Your Soul        0
# 1       Mamie Smith      Keep A Song In Your Soul        0
# 2       Mamie Smith      Keep A Song In Your Soul        0
# 3       Mamie Smith      Keep A Song In Your Soul        0
# 4       Mamie Smith      Keep A Song In Your Soul        0
# ...             ...                           ...      ...
# 684532   Carpenters  It's Going To Take Some Time    14999
# 684533   Carpenters  It's Going To Take Some Time    14999
# 684534   Carpenters  It's Going To Take Some Time    14999
# 684535   Carpenters  It's Going To Take Some Time    14999
# 684536   Carpenters  It's Going To Take Some Time    14999
#
#                                                sent
# 0          it's a junkie dream makes you so uptight
# 1       yeah it's halloween tonight and every night
# 2             see you scratch (see it on) your skin
# 3                             your sandpaper throat
# 4                                 you're a symphony
# ...                                             ...
# 684532          It's gonna take some time this time
# 684533                  No matter what I've planned
# 684534   But like the young trees in the wintertime
# 684535                       I'll learn how to bend
# 684536                                   Repeat (*)
#
# [684537 rows x 4 columns]

# %%
df3 = pd.read_csv('lyrics_song_genres_15k.csv')

# %%
df3.head()
# Out:
#          artist                                          song_name  \
# 0   Mamie Smith                           Keep A Song In Your Soul
# 1   Mamie Smith                                       Golfing Papa
# 2   Mamie Smith                       Don't You Advertise Your Man
# 3   Mamie Smith  Miss Jenny's Ball (aka There'll Be No Freebies...
# 4  Bessie Smith          Nobody Knows You When You're Down and Out
#
#   closest_genre                                              lyric  \
# 0         Blues  it's a junkie dream makes you so uptight\nyeah...
# 1         Blues  I know a triflin' man\nThey call him Triflin' ...
# 2         Blues  Punctured bicycle\nOn a hillside desolate\nWil...
# 3         Blues  I'll fake it through the day\nwith some help\n...
# 4          Jazz  I was happy in the haze of a drunken hour\nBut...
#
#    length_lyric
# 0           177
# 1           176
# 2           154
# 3           200
# 4           200

# %%
df3.closest_genre.unique()
# Out:
# array(['Blues', 'Jazz', 'Folk', 'Pop', 'Country', 'Rock', 'Electronic',
#        'Punk', 'Hip Hop', 'Metal', 'Reggae'], dtype=object)

# %%
df3.groupby('closest_genre').song_name.count()
# Out:
# closest_genre
# Blues         1524
# Country        578
# Electronic     434
# Folk           675
# Hip Hop        891
# Jazz          1900
# Metal          313
# Pop            926
# Punk           548
# Reggae         121
# Rock          7090
# Name: song_name, dtype: int64

# %%
df3.groupby('closest_genre').length_lyric.sum()
# Out:
# closest_genre
# Blues          342588
# Country        130085
# Electronic     101608
# Folk           157734
# Hip Hop        392147
# Jazz           330667
# Metal           65335
# Pop            237767
# Punk           120021
# Reggae          30767
# Rock          1517466
# Name: length_lyric, dtype: int64

# %%
# Coba dulu semua genre
# Liat performanya gimana (lama waktu)

# %%
df3.query('closest_genre=="Jazz"')
# Out:
#                artist                                  song_name  \
# 4        Bessie Smith  Nobody Knows You When You're Down and Out
# 5        Bessie Smith           'Tain't Nobody's Bizness If I Do
# 6        Bessie Smith              Send Me to the 'Lectric Chair
# 7        Bessie Smith             Need a Little Sugar in My Bowl
# 8        Bessie Smith                        Young Woman's Blues
# ...               ...                                        ...
# 14908     Nina Simone                                O-o-h Child
# 14914         Caravan                 In The Land Of Grey & Pink
# 14951    Paul Desmond                              Autumn Leaves
# 14965  Donny Hathaway                          Little Ghetto Boy
# 14990  Donny Hathaway                     What's Going On - Live
#
#       closest_genre                                              lyric  \
# 4              Jazz  I was happy in the haze of a drunken hour\nBut...
# 5              Jazz  There ain't nothing I can do, or nothing I can...
# 6              Jazz  Judge you wanna hear my plea\nBefore you open ...
# 7              Jazz  One more little one\nI'll go down\nAnd stay do...
# 8              Jazz  I hate to see that evening sun go down\nI hate...
# ...             ...                                                ...
# 14908          Jazz  Traditional\n\nChildren go where I send you,\n...
# 14914          Jazz  In the land of grey and pink where only boy-sc...
# 14951          Jazz  The problem is all inside your head\nShe said ...
# 14965          Jazz  Yes, this is the Ghetto, sure nuff now\nDon't ...
# 14990          Jazz  Go away little girl\nGo away little girl\nI'm ...
#
#        length_lyric
# 4               200
# 5               171
# 6               215
# 7               146
# 8               141
# ...             ...
# 14908           271
# 14914           234
# 14951           219
# 14965           251
# 14990           176
#
# [1900 rows x 5 columns]

# %%
df3_samples = df3.groupby("closest_genre").sample(n=100, random_state=1)

# %%
df3_samples.groupby('closest_genre').length_lyric.sum()
# Out:
# closest_genre
# Blues         22898
# Country       23580
# Electronic    23136
# Folk          22895
# Hip Hop       43458
# Jazz          17389
# Metal         20040
# Pop           26116
# Punk          19512
# Reggae        25762
# Rock          21278
# Name: length_lyric, dtype: int64

# %%
df3_samples.groupby('closest_genre').song_name.count()
# Out:
# closest_genre
# Blues         100
# Country       100
# Electronic    100
# Folk          100
# Hip Hop       100
# Jazz          100
# Metal         100
# Pop           100
# Punk          100
# Reggae        100
# Rock          100
# Name: song_name, dtype: int64

# %%
df3_samples.to_csv('sample_100_15k.csv', index=False)
